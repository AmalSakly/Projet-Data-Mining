# %%
# Import the required libraries.
import tweepy
import pandas as pd
import matplotlib.pyplot as plt


consumer_key = "Tippg04Ns8bfIZtE3uMprKEym" 
consumer_secret = "qHjBkD4CBX67rHPenKu96c7W5Tsv59t9BGBVsm0pXM0oLatOS8"
access_key= "1328070400136400905-ZOCtds4L0DD3LqMJ2r9rZHSyAi75Xu"
access_secret = "qX3pBBD42A1dAZDPXx2DGcH0T0hcr4e5Oxw40YwR9wTnc"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

result=[]

for tweet in tweepy.Cursor(api.search,q="#",
                           lang="en",
                           since="2020-01-01").items(5):
    result.append(tweet)
    #print (tweet.created_at, tweet.text)
    leng= len(result)
print(leng)
# Out:
# 5

# %%
def toDataFrame(tweets):

    DataSet = pd.DataFrame()
    DataSet['tweetID'] = [tweet.id for tweet in tweets]
    DataSet['tweetText'] = [tweet.text for tweet in tweets]
    DataSet['tweetRetweetCt'] = [tweet.retweet_count for tweet in tweets]
    DataSet['tweetFavoriteCt'] = [tweet.favorite_count for tweet in tweets]
    DataSet['tweetSource'] = [tweet.source for tweet in tweets]
    DataSet['tweetCreated'] = [tweet.created_at for tweet in tweets]
    DataSet['userID'] = [tweet.user.id for tweet in tweets]
    DataSet['userScreen'] = [tweet.user.screen_name for tweet in tweets]
    DataSet['userName'] = [tweet.user.name for tweet in tweets]
    DataSet['userCreateDt'] = [tweet.user.created_at for tweet  in tweets]
    DataSet['userDesc'] = [tweet.user.description for tweet in tweets]
    DataSet['userFollowerCt'] = [tweet.user.followers_count for tweet  in tweets]
    DataSet['userFriendsCt'] = [tweet.user.friends_count for tweet  in tweets]
    DataSet['userLocation'] = [tweet.user.location for tweet in tweets]
    DataSet['userTimezone'] = [tweet.user.time_zone for tweet in tweets]
    DataSet.to_csv('file1.csv') 

    return DataSet

# %%
#Pass the tweets list to the above function to create a DataFrame
DataSet = toDataFrame(result)

# %%
# Let's check the top 5 records in the Data Set
DataSet.head(20)
# Out:
#                 tweetID                                          tweetText  \
# 0   1330824930548707330  @RichardBurgon Clearly, the task of the Labour...
# 1   1330824930548703233  RT @apalebluedot_: @_naive_girl Not less than ...
# 2   1330824930548609026  He deserves it! 😭😭😭\n#GOT7 #갓세븐 @GOT7Official ...
# 3   1330824930502582272  @VanguardYiddish @ForteEddie @LibertyHangout @...
# 4   1330824930464821249  @leftlibbot The government will have you worri...
# 5   1330824930448044033  Another £3bn for the NHS? At what point do we ...
# 6   1330824930435375106  #Gaming GTA 5 NUEVO DLC SUMMER SPECIAL - GTA V...
# 7   1330824930435362816             @Lorm_Tai_Peak I love ur shots of bw 💕
# 8   1330824930431295489                 Love tweating For fun 😂 Hay. Hallo
# 9   1330824930431209473  @tonygallagher07 @steviebhoy07 @Bhoy67john I'm...
# 10  1330824930427080710                           heavenly sexy zookeeper.
# 11  1330824930422714369  RT @parkjiminpics: oh my god jimin https://t.c...
# 3                         Sweet Cee Voted 💙 2017-05-26 03:30:38
# 4                               leftauthbot 2020-10-09 19:21:39
# 5                               Simon Dover 2009-02-09 16:29:38
# 6                             @network_easy 2012-04-07 04:19:25
# 7                                       𝖒𝖊𝖔 2020-04-03 08:52:26
# 8                             Ebony Jenkins 2015-10-21 18:43:11
# 9                                    Divers 2011-11-28 21:11:44
# 10                            costume ideas 2015-10-22 12:11:42
# 11                                      고리➰ 2020-10-21 11:19:12
# 12                            ً nia | D-DAY 2020-06-15 14:30:30
# 13           Control Components Anglia Ltd. 2020-02-12 14:43:42
# 14                                        ً 2013-02-09 22:57:58
# 15                      RocSearch Tech Jobs 2015-10-12 15:11:06
# 16                                    A.A🔴🔴 2019-09-11 17:16:45
# 17                                     _jny 2020-06-27 10:55:49
# 18                            life goes mon 2015-10-27 14:32:49
# 19                  Révolutionnaire révolté 2020-11-16 03:52:43
#
#                                              userDesc  userFollowerCt  \
# 0                                                                 151
# 1                           SidNaaz - Do jism ek jaan             101
# 2                       Filo Ahgase | GOT7 | 10.26.19             729
# 3   The rest of us have to deal with reality; so c...              50
# 4                                                                   4
# 5                                                                  47
# 6   #guestposting #EasyBranches #guestposts #Socia...           20006
# 7                      missin’ u everyday @winmetawin               9
# 8                                    My life in Tweat              17
# 9                                   Get The Shamen On             558
# 10  Ladies! Stuck for ideas for a Halloween costum...             274
# 11  spr\n지구의 평화를 위해서 7명 모두 같이 사겨조라 귀엽다 이쁘니들 지뢰없음 |...               0
# 12  𖣂 jae. 𓂅 — ten !  ꏍ   hyu   %  gyu  !!  𝗁a𝗋𝗎  ...            1508
# 13  Your local industrial automation & control dis...              57
# 14                         ❝ 𝙇𝙤𝙤𝙠𝙨 𝙘𝙖𝙣 𝙗𝙚 𝙙𝙚𝙘𝙚𝙞𝙫𝙞𝙣𝙜 ❞            1488
# 15  Hi, we’re Roc Search. Here we tweet our latest...             376
# 16                had a bio but telles crossed it out             161
# 17                                                                  2
# 18                       city of flowers, city of mon            1119
# 19  j'aime mon prochain💯%car tôt ou tard...on ira ...               1
#
#     userFriendsCt                                       userLocation  \
# 0             388
# 1             315
# 2             997
# 3             274                                      United States
# 4               6
# 5             143                             Whitwell, Ventnor, IOW
# 6           15373                                   Global Worldwide
# 7             174
# 8               0                                            America
# 9            1586                                           Maryhill
# 10             47                                      Transylvania
# 11            254
# 12           1281  🥢SHE/HER | 5TEEN!!\n★ READ CARRD BYF ★\nYeah 变...
# 13            121                                            Norwich
# 14            727                                              MV|MS
# 15            395                            England, United Kingdom
# 16            376
# 17             16
# 18            804                                            she/her
# 19             27
#
#    userTimezone
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
# 6          None
# 7          None
# 8          None
# 9          None
# 10         None
# 11         None
# 12         None
# 13         None
# 14         None
# 15         None
# 16         None
# 17         None
# 18         None
# 19         None

# %%
DataSet.info()

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
